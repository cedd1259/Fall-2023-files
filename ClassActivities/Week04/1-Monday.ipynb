# %% [markdown]
# # Monday, September 11
# ## Announcements and Reminders
# - Chapter 5 Reading due today, but definitely by Wednesday
# - Programming Assignment 2: Available soon, due next Monday
#
# ## Questions:

# %% [markdown]
# ## Activity: Turtles, Geometry, and Fractals
#
# We will continue using the python turtle to get visual feedback on how functions work.
#
# Our goal for today is to produce shapes like the following, without writing hundreds of lines of code.

# %% [markdown]
# <!-- ![Spiral](spiral.png) -->
# <div>
# <img src="spiral.png" width="800"/>
# </div>

# %% [markdown]
# **Important**: I have found a better turtle module called `ColabTurtlePlus` that is easer to use than the `ipyturtle3` we were using last time.
#
# Before you start executing any code, run the following command in the terminal:
#
# `pip install ColabTurtlePlus`
#
# Or, just execute the following cell in the notebook:

# %%
# !pip install ColabTurtlePlus
# Out:
# Collecting ColabTurtlePlus
#   Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl (31 kB)
# Installing collected packages: ColabTurtlePlus
# Successfully installed ColabTurtlePlus-2.0.1

# %% [markdown]
# We will create a turtle and screen to use throughout the activity.  Let's call our turtle "Tracy" this time.  Because clearly that is the best name for a turtle.

# %%
from ColabTurtlePlus.Turtle import *
# Every time we want to have a new screen, we will use the following commands to create a new screen and a new turtle object:
# Name the screen and turtle objects:
clearscreen()
Sandbox = Screen()
Tracy = Turtle()
# Set properties for Sandbox and Tracy
Sandbox.bgcolor(10, 0, 40)
Tracy.shape("turtle")
Tracy.color("green")
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:rgb(10,0,40);stroke:;stroke-width:1"/>
#
#
#
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90,400.0,300.0) translate(400.0, 300.0)">
# <path style="stroke:green;fill-rule:evenodd;fill:green;fill-opacity:1;" transform="skewX(0) scale(1,1)" d="m 1.1536693,-18.56101 c -2.105469,1.167969 -3.203125,3.441407 -3.140625,6.5 l 0.011719,0.519532 -0.300782,-0.15625 c -1.308594,-0.671875 -2.828125,-0.824219 -4.378906,-0.429688 -1.9375,0.484375 -3.8906253,2.089844 -6.0117193,4.9257825 -1.332031,1.785156 -1.714843,2.644531 -1.351562,3.035156 l 0.113281,0.125 h 0.363281 c 0.71875,0 1.308594,-0.265625 4.6679693,-2.113282 1.199219,-0.660156 2.183594,-1.199218 2.191406,-1.199218 0.00781,0 -0.023437,0.089844 -0.074218,0.195312 -0.472657,1.058594 -1.046876,2.785156 -1.335938,4.042969 -1.054688,4.574219 -0.351562,8.453125 2.101562,11.582031 0.28125,0.355469 0.292969,0.253906 -0.097656,0.722656 -2.046875,2.4609375 -3.027344,4.8984375 -2.734375,6.8046875 0.050781,0.339844 0.042969,0.335938 0.679688,0.335938 2.023437,0 4.15625,-1.316407 6.21875,-3.835938 0.222656,-0.269531 0.191406,-0.261719 0.425781,-0.113281 0.730469,0.46875 2.460938,1.390625 2.613281,1.390625 0.160157,0 1.765625,-0.753906 2.652344,-1.246094 0.167969,-0.09375 0.308594,-0.164062 0.308594,-0.160156 0.066406,0.105468 0.761719,0.855468 1.085937,1.171875 1.613282,1.570312 3.339844,2.402343 5.3593747,2.570312 0.324219,0.02734 0.355469,0.0078 0.425781,-0.316406 0.375,-1.742187 -0.382812,-4.058594 -2.1445307,-6.5585935 l -0.320312,-0.457031 0.15625,-0.183594 c 3.2460927,-3.824218 3.4335927,-9.08593704 0.558593,-15.816406 l -0.050781,-0.125 1.7382807,0.859375 c 3.585938,1.773437 4.371094,2.097656 5.085938,2.097656 0.945312,0 0.75,-0.863281 -0.558594,-2.507812 C 11.458356,-11.838353 8.3333563,-13.268041 4.8607003,-11.721166 l -0.363281,0.164063 0.019531,-0.09375 c 0.121094,-0.550781 0.183594,-1.800781 0.121094,-2.378907 -0.203125,-1.867187 -1.035157,-3.199218 -2.695313,-4.308593 -0.523437,-0.351563 -0.546875,-0.355469 -0.789062,-0.222657" />
# </g>
#       </svg>

# %% [markdown]
# Now let's draw a square.  First, the slow way:

# %%
### SETUP ###
clearscreen()
Sandbox = Screen()
Tracy = Turtle()
Sandbox.bgcolor(10, 0, 40)
Tracy.shape("turtle")
Tracy.color("orange")
### END SETUP ###

def walk_turn():
    Tracy.forward(100)
    Tracy.left(90)
    print(Tracy.position())
    if Tracy.position()!!(0.0, 0.0)
    walk_turn()
walk_turn()

walk_turn()
walk_turn()
walk_turn()
walk_turn()
# Out:
#   Cell In[11], line 14
#     if Tracy.position()!!(0.0, 0.0)
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Now try to modify the code above to draw the square using a function to avoid repeating as many identical lines of code.  Maybe define a function that combines the forward and turn steps.
#
# **Note**: If you know what they are, you might be tempted to use *loops* to make this simpler.  Hold that thought.  The goal of this activity is to use functions instead of loops.

# %% [markdown]
# ### Recursion to the rescue
#
# Can we do even better?  A function tells Tracy what to do.  Can the function tell Tracy what to do next as well?  Try telling Tracy to walk, turn, and repeat.

# %%
### SETUP ###
clearscreen()
Sandbox = Screen()
Tracy = Turtle()
Sandbox.bgcolor(10, 20, 0)
Tracy.shape("turtle")
Tracy.color("orange")
### END SETUP ###

def walk_turn(dist, ang):
  Tracy.forward(dist)
  Tracy.left(ang)
  if Tracy.position() != (0.0, 0.0):
    walk_turn(dist - 5, ang)
  #Fill in the function

#Call the function
walk_turn(150,90)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:rgb(10,20,0);stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="550.0" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="550.0" y1="300.0" x2="550.0" y2="155.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="550.0" y1="155.0" x2="410.0" y2="155.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="410.0" y1="155.0" x2="410.0" y2="290.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="410.0" y1="290.0" x2="540.0" y2="290.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="540.0" y1="290.0" x2="540.0" y2="165.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="540.0" y1="165.0" x2="420.0" y2="165.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="420.0" y1="165.0" x2="420.0" y2="280.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="420.0" y1="280.0" x2="530.0" y2="280.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="530.0" y1="280.0" x2="530.0" y2="175.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="530.0" y1="175.0" x2="430.0" y2="175.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="430.0" y1="175.0" x2="430.0" y2="270.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="430.0" y1="270.0" x2="520.0" y2="270.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="520.0" y1="270.0" x2="520.0" y2="185.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="520.0" y1="185.0" x2="440.0" y2="185.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="440.0" y1="185.0" x2="440.0" y2="260.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="440.0" y1="260.0" x2="510.0" y2="260.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="510.0" y1="260.0" x2="510.0" y2="195.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="510.0" y1="195.0" x2="450.0" y2="195.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="450.0" y1="195.0" x2="450.0" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="450.0" y1="250.0" x2="500.0" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="500.0" y1="250.0" x2="500.0" y2="205.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="500.0" y1="205.0" x2="460.0" y2="205.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="460.0" y1="205.0" x2="460.0" y2="240.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="460.0" y1="240.0" x2="490.0" y2="240.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="490.0" y1="240.0" x2="490.0" y2="215.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="490.0" y1="215.0" x2="470.0" y2="215.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="470.0" y1="215.0" x2="470.0" y2="230.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="470.0" y1="230.0" x2="480.0" y2="230.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="480.0" y1="230.0" x2="480.0" y2="225.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="480.0" y1="225.0" x2="480.0" y2="225.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="480.0" y1="225.0" x2="480.0" y2="220.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="480.0" y1="220.0" x2="470.0" y2="220.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="470.0" y1="220.0" x2="470.0" y2="235.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="470.0" y1="235.0" x2="490.0" y2="235.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="490.0" y1="235.0" x2="490.0" y2="210.0" stroke-linecap="round" ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     walk_turn(dist - 5, ang)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>   #Fill in the function
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> #Call the function
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> walk_turn(150,90)
#
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> Tracy.left(ang)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> if Tracy.position() != (0.0, 0.0):
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>   walk_turn(dist - 5, ang)
#
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> Tracy.left(ang)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> if Tracy.position() != (0.0, 0.0):
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>   walk_turn(dist - 5, ang)
#
#     [... skipping similar frames: walk_turn at line 14 (124 times)]
#
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> Tracy.left(ang)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> if Tracy.position() != (0.0, 0.0):
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>   walk_turn(dist - 5, ang)
#
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> def walk_turn(dist, ang):
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>   Tracy.forward(dist)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>   Tracy.left(ang)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>   if Tracy.position() != (0.0, 0.0):
#
# File ~/.python/current/lib/python3.10/site-packages/ColabTurtlePlus/Turtle.py:862, in RawTurtle.forward(self, units)
#     860 alpha = math.radians(self.turtle_degree)
#     861 new_pos = (self.turtle_pos[0] + units * self.screen.xscale * math.cos(alpha), self.turtle_pos[1] + units * abs(self.screen.yscale) * math.sin(alpha))
# --> 862 self.screen._moveToNewPosition(new_pos,units, turtle=self)
#
# File ~/.python/current/lib/python3.10/site-packages/ColabTurtlePlus/Turtle.py:364, in _Screen._moveToNewPosition(self, new_pos, units, turtle)
#     355             turtle.svg_lines_string += \
#     356             """<line x1="{x1}" y1="{y1}" x2="{x2}" y2="{y2}" stroke-linecap="round" style="stroke:{pcolor};stroke-width:{pwidth}" />""".format(
#     357                 x1=initial_pos[0],
#    (...)
#     361                 pcolor=turtle.pen_color,
#     362                 pwidth=turtle.pen_width)
#     363         initial_pos = turtle.turtle_pos
# --> 364         self._updateDrawing(turtle=turtle)
#     365         units -= dunits
#     366 else:
#     367     # world mode with aspect ratio of axes different than aspect ratio of the window
#
# File ~/.python/current/lib/python3.10/site-packages/ColabTurtlePlus/Turtle.py:327, in _Screen._updateDrawing(self, turtle, delay)
#     325         self.drawing_window.update(HTML(self._generateSvgDrawing()))
#     326         if delay:
# --> 327             time.sleep(turtle.timeout)
#     328 else:
#     329     self.drawing_window.update(HTML(self._generateSvgDrawing()))
#
# KeyboardInterrupt:

# %% [markdown]
# ### Polygons
#
# The code above should be able to draw shapes other than squares.  How could you tell it to draw an octagon?
#
# Actually, why don't we just write a function `polygon(sides, size)` that draws a polygon with `sides` sides each of size `size`:

# %%
### SETUP ###
clearscreen()
Sandbox = Screen()
Tracy = Turtle()
Sandbox.bgcolor(10, 20, 20)
Tracy.shape("turtle")
Tracy.color("orange")
### END SETUP ###

def polygon(sides, size, counter=1):
  print(counter)
  Tracy.forward(size)
  Tracy.left(360/sides)
  if counter < sides:
    polygon(sides, size, counter+1)

  
  #Fill in the function

#Call the function
polygon(11, 75)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:rgb(10,20,20);stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="475.0" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="475.0" y1="300.0" x2="538.094" y2="259.452" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="538.094" y1="259.452" x2="569.25" y2="191.23" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="569.25" y1="191.23" x2="558.576" y2="116.993" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="558.576" y1="116.993" x2="509.461" y2="60.312" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="509.461" y1="60.312" x2="437.499" y2="39.182" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="437.499" y1="39.182" x2="365.537" y2="60.312" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="365.537" y1="60.312" x2="316.422" y2="116.993" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="316.422" y1="116.993" x2="305.748" y2="191.23" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="305.748" y1="191.23" x2="336.904" y2="259.452" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="336.904" y1="259.452" x2="399.998" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="399.998" y1="300.0" x2="474.998" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="474.998" y1="300.0" x2="538.092" y2="259.452" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="538.092" y1="259.452" x2="569.248" y2="191.23" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="569.248" y1="191.23" x2="558.574" y2="116.993" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="558.574" y1="116.993" x2="509.459" y2="60.312" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="509.459" y1="60.312" x2="437.497" y2="39.182" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="437.497" y1="39.182" x2="365.535" y2="60.312" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="365.535" y1="60.312" x2="316.42" y2="116.993" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="316.42" y1="116.993" x2="305.746" y2="191.23" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="305.746" y1="191.23" x2="336.902" y2="259.452" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="336.902" y1="259.452" x2="399.996" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="399.996" y1="300.0" x2="474.996" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="474.996" y1="300.0" x2="538.09" y2="259.452" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="538.09" y1="259.452" x2="569.246" y2="191.23" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="569.246" y1="191.23" x2="558.572" y2="116.993" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="558.572" y1="116.993" x2="509.457" y2="60.312" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="509.457" y1="60.312" x2="437.495" y2="39.182" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="437.495" y1="39.182" x2="365.533" y2="60.312" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="365.533" y1="60.312" x2="316.418" y2="116.993" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="316.418" y1="116.993" x2="305.744" y2="191.23" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="305.744" y1="191.23" x2="336.9" y2="259.452" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="336.9" y1="259.452" x2="399.994" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:1" /><line x1="399.994" y1="300.0" x2="474.994" y2="300.0" stroke-linecap="round" style="stroke:orange;stro ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 15 line 2
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     polygon(sides, size)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>   #Fill in the function
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> #Call the function
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> polygon(11, 75)
#
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> Tracy.left(360/sides)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> if Tracy.position() != (0.0, 0.0):
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>   polygon(sides, size)
#
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> Tracy.left(360/sides)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> if Tracy.position() != (0.0, 0.0):
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>   polygon(sides, size)
#
#     [... skipping similar frames: polygon at line 14 (390 times)]
#
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> Tracy.left(360/sides)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> if Tracy.position() != (0.0, 0.0):
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>   polygon(sides, size)
#
# /workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> def polygon(sides, size):
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>   Tracy.forward(size)
# ---> <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>   Tracy.left(360/sides)
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>   if Tracy.position() != (0.0, 0.0):
#      <a href='vscode-notebook-cell://codespaces%2Bopulent-yodel-jj59j444rpxj2qwvq/workspaces/Fall-2023-files/ClassActivities/Week04/1-Monday.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     polygon(sides, size)
#
# File ~/.python/current/lib/python3.10/site-packages/ColabTurtlePlus/Turtle.py:967, in RawTurtle.left(self, angle)
#     965 if not isinstance(angle, (int,float)):
#     966     raise ValueError('Degrees must be a number.')
# --> 967 self.right(-1 * angle)
#
# File ~/.python/current/lib/python3.10/site-packages/ColabTurtlePlus/Turtle.py:929, in RawTurtle.right(self, angle)
#     927 self.stretchfactor = 1,1
#     928 self.timeout = self.timeout*abs(deg)/90+0.001
# --> 929 self.screen._updateDrawing(self)
#     930 self.turtle_degree = (self.turtle_degree + deg) % 360
#     931 self.turtle_orient = self._turtleOrientation()
#
# File ~/.python/current/lib/python3.10/site-packages/ColabTurtlePlus/Turtle.py:327, in _Screen._updateDrawing(self, turtle, delay)
#     325         self.drawing_window.update(HTML(self._generateSvgDrawing()))
#     326         if delay:
# --> 327             time.sleep(turtle.timeout)
#     328 else:
#     329     self.drawing_window.update(HTML(self._generateSvgDrawing()))
#
# KeyboardInterrupt:

# %% [markdown]
# Just for fun, see what happens if you modify `sides` or `size` when you tell Tracy to "repeat".  Could you draw a cool spiral?

# %%
### SETUP ###
clearscreen()
Sandbox = Screen()
Tracy = Turtle()
Sandbox.bgcolor(30, 10, 0)
Tracy.shape("turtle")
Tracy.color("orange")
### END SETUP ###

def spiral():
  pass
  #Fill in the function

#Call the function
spiral()

# %% [markdown]
# ### Fractals!
#
# Try executing the code below:

# %%
### SETUP ###
clearscreen()
Sandbox = Screen()
Tracy = Turtle()
Sandbox.bgcolor(14,81,53)
Tracy.shape("triangle")
Tracy.color(212,206,70)
### END SETUP ###

Tracy.speed(100)
def triangle(sidelength, sidecount=0):
  if sidecount < 3:
    Tracy.pendown()
    Tracy.forward(sidelength)
    Tracy.left(120)
    triangle(sidelength, sidecount+1)

def triforce(size,depth,counter=0):
  if counter < depth:
    triforce(size/2, depth, counter+1)
    Tracy.penup()
    Tracy.forward(size*2)
    Tracy.left(120)
    triforce(size/2, depth, counter+1)
    Tracy.penup()
    Tracy.forward(size*2)
    Tracy.left(120)
    triforce(size/2, depth, counter+1)
    Tracy.penup()
    Tracy.forward(size*2)
    Tracy.left(120)
  else:
    triangle(size*2)


#change start position to center image
Tracy.penup()
Tracy.goto(-150,-100)
triforce(150,3)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:rgb(14,81,53);stroke:;stroke-width:1"/>
#
#
#         <line x1="250.0" y1="400.0" x2="287.5" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="287.5" y1="400.0" x2="268.75" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="268.75" y1="367.524" x2="250.0" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="325.0" y1="400.0" x2="306.25" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="306.25" y1="367.524" x2="287.5" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="287.5" y1="400.0" x2="325.0" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="287.5" y1="335.048" x2="268.75" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="268.75" y1="367.524" x2="306.25" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="306.25" y1="367.524" x2="287.5" y2="335.048" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="400.0" y1="400.0" x2="381.25" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="381.25" y1="367.524" x2="362.5" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="362.5" y1="400.0" x2="400.0" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="362.5" y1="335.048" x2="343.75" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="343.75" y1="367.524" x2="381.25" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="381.25" y1="367.524" x2="362.5" y2="335.048" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="325.0" y1="400.0" x2="362.5" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="362.5" y1="400.0" x2="343.75" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="343.75" y1="367.524" x2="325.0" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="325.0" y1="270.096" x2="306.25" y2="302.572" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="306.25" y1="302.572" x2="343.75" y2="302.572" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="343.75" y1="302.572" x2="325.0" y2="270.096" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="287.5" y1="335.048" x2="325.0" y2="335.048" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="325.0" y1="335.048" x2="306.25" y2="302.572" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="306.25" y1="302.572" x2="287.5" y2="335.048" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="362.5" y1="335.048" x2="343.75" y2="302.572" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="343.75" y1="302.572" x2="325.0" y2="335.048" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="325.0" y1="335.048" x2="362.5" y2="335.048" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="550.0" y1="400.0" x2="531.25" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="531.25" y1="367.524" x2="512.5" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="512.5" y1="400.0" x2="550.0" y2="400.0" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="512.5" y1="335.048" x2="493.75" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><line x1="493.75" y1="367.524" x2="531.25" y2="367.524" stroke-linecap="round" style="stroke:rgb(212,206,70);stroke-width:1" /><li ...

# %% [markdown]
# Part of what makes the code above complicated is that we are calling the function recursively three times inside itself. To see what is going on better, let's look at one that only calls itself once each time through.

# %%
### SETUP ###
clearscreen()
Sandbox = Screen()
Tracy = Turtle()
Sandbox.bgcolor(0, 0, 0)
Tracy.shape("turtle")
Tracy.color("pink")
### END SETUP ###

Tracy.speed(10)
def circles(size, depth, counter=0):
  if counter < depth:
    circles(0.5*size, depth, counter+1)
    # "stamp" so we can see where the circle starts
    # Tracy.stamp()
    # Move start to a quarter way around a circle
    Tracy.circle(size,90)
    # Draw a circle
    Tracy.circle(size)


circles(200,5)

# %% [markdown]
# ## What's next?
#
# Let's add a little color.  Can we write a function that colors the sides of a polygon with three colors, repeating in sequence?  How can we control that?
